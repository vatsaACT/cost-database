# %%
from sqlalchemy import create_engine
import pandas as pd
import openpyxl

# %%
engine = create_engine(
    "postgresql://postgres:mypassword@localhost:5432/postgres"
)

conn = engine.connect()
print("Connected to PostgreSQL")
conn.close()
# Out:
# Connected to PostgreSQL

# %%
df = pd.read_excel("GaN Inverter BOM_Elec.xlsx")

df.to_sql(
    name="GaN_eBOM",
    con=engine,
    if_exists="replace",   # or "append"
    index=False
)
# Out:
# 195

# %%
query = """
SELECT *
FROM "GaN_eBOM"
LIMIT 5;
"""

df_query = pd.read_sql(query, con=engine)

# %%
print(df_query)
# Out:
#    level         item_number  \
# 0    2.0           EUCM00037
# 1    2.0           EUCM00010
# 2    2.0           ECXX00035
# 3    2.0           EFUS00033
# 4    2.0  HLC1206X6S226K250N
#
#                                            item_name                      mfg  \
# 0      Yitran MODEM IT900A-YTREB (9.11.164) (FCC\60)  Yitran Technologies LTD
# 1                   IC HOME AUTOMATION MODEM 16-SOIC                      NXP
# 2                       CAP TANT POLY 100UF 25V 2917                   Vishay
# 3  15 A 350 V AC 125 V DC Fuse Cartridge, Ceramic...             Bel Fuse Inc
# 4                          CAP CER 22UF 25V X6S 1206                   Hongda
#
#                                   mpn revision     item_phase  \
# 0    IT900A-YTREB (9.11.164) (FCC\60)        2      In Design
# 1                    TDA5051AT/C1,518        1  In Production
# 2  T55D107M025C0060, T55D107M025#0060        1  In Production
# 3          0683G9150-01, 0683G9150-0#        1  In Production
# 4                  HLC1206X6S226K250N        1      In Design
#
#              item_category   qty   uom procurement_type  \
# 0       IC, Communications   1.0  each              MTS
# 1       IC, Communications   1.0  each              OTS
# 2       Capacitor, General   4.0  each              OTS
# 3                     Fuse   2.0  each              OTS
# 4  Capacitor, Ceramic Chip  18.0  each              OTS
#
#                                 reference_designator  excl   cat  \
# 0                                                IC2  None  PCBA
# 1                                                U18  None  PCBA
# 2                             C138, C145, C169, C253  None  PCBA
# 3                                       FUSE1, FUSE2  None  PCBA
# 4  C4, C5, C11, C16, C17, C18, C26, C27, C32, C23...  None  PCBA
#
#   parent cleaned  expl_qty  true_qty  cel_UP  cel_EP  cel_MFG
# 0      APRD00056       1.0       1.0  5.1000    5.10      NaN
# 1      APRD00056       1.0       1.0  3.0492    3.05  TOSHIBA
# 2      APRD00056       4.0       4.0  0.4560    1.82      NaN
# 3      APRD00056       2.0       2.0  0.7606    1.52      NaN
# 4      APRD00056      18.0      18.0  0.0843    1.52      NaN
